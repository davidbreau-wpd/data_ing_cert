# %%
from models import Vestas_Report; from pathlib import Path

folder_path = Path("data") / "input"
file_name = 'vestas_report_example.pdf'
file_path = Path(folder_path) / file_name
# Out:
# /home/utilisateur/Projets/pdf_transformation/venv/lib/python3.11/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
vestas_report = Vestas_Report(file_path)

# %%
vestas_report.get_header_informations()
# Out:
# {'turbine_number': '232',
#  'service_order': '6114',
#  'pad_no': 'HOU',
#  'turbine_type': 'V136',
#  'start_date': '17.10.2023',
#  'end_date': '17.10.2023',
#  'customer_address': ['ENERGIE'],
#  'date_and_time_of_receipt': '19.03.2023 22:15:02',
#  'reason_for_call_out': 'Check ICPE Electrical V136'}

# %%
import pandas as pd; pd.set_option('display.max_rows', None); pd.set_option('display.max_columns', None); pd.set_option('display.width', None); pd.set_option('display.max_colwidth', None) 

full_table=vestas_report._extract_full_table()

# %%
full_table
# Out:
#        0  \
# 0   0010
# 1      0
# 2   0.01
# 3      1
# 4   1.01
# 5   1.02
# 6
# 7   1.03
# 8
# 9   1.04
# 10  1.05
# 11  1.06
# 12     2
# 13  2.01
# 14  2.02
# 15
# 16  2.03
# 17
# 18     3
# 19  3.01
# 20  3.02
# 21
# 22  3.03
# 23  3.04
# 24
# 25  3.05
# 26
# 27  3.06
# 28
# 29  3.07
# 30
# 31     4
# 32  4.01
# 33
# 34  4.02
# 35  4.03
# 36  4.04
# 37  4.05
# 38  4.06
# 39
# 40  4.08
# 41
#
#                                                                                                                                                         1  \
# 0                                                                                                                          Check ICPE Electrical V112-3MW
# 1                                                                                                                                                    eSIF
# 2                                                                                                                                   0. DMS: 0093-0083 V03
# 3                                                                                                                                                  Safety
# 4                                                                                                                                    Two persons present.
# 5                     Trained in and aware of the contents of the Vestas Corporate OH and SManual including ‘Working with Hazardous Materials’ and Safety
# 6                                                                                                              Regulations for Operators and Technicians.
# 7                  Be sure to know the general recommendations regarding the followingpoints: For safety reasons, note the location of the emergency stop
# 8                         buttons. Please refer to documentation “Safety Regulations forOperators and Technicians” of the corresponding turbine platform.
# 9                                                                                                                                Locking of rotor/blades.
# 10                                                                                                                                    Hearing protection.
# 11                                                                                                                                       Hydraulic tools.
# 12                                                                                                                                             Article 16
# 13                                   Check that wind turbine is clean. Check that nocombustible orinflammable material is stored inside the wind turbine.
# 14                       L'intérieur de l'aérogénérateur est maintenu propre. L'entreposage àl'intérieur de l'aérogénérateur de matériaux combustibles ou
# 15                                                                                                                             inflammables est interdit.
# 16                                                                                                                                Remarks: (as a comment)
# 17
# 18                                                                                                                                             Article 17
# 19                                                                                                                Verify Stop Button is working properly.
# 20  Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt en
# 21                                                                                    application des préconisations du constructeur de l'aérogénérateur.
# 22                                                                                                      Verify Emergency Stop Button is working properly.
# 23     Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt
# 24                                                                        d'urgence en application des préconisations du constructeur del'aérogénérateur.
# 25                                                                                                     Perform a VOG Test based on relevant platform SWI.
# 26
# 27     Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt
# 28                                                    depuis un régime de survitesse en application des préconisations duconstructeur de l'aérogénérateur
# 29                                                                                                                                Remarks: (as a comment)
# 30
# 31                                                                                                                                         Article 18 III
# 32                  Contrôle des systèmes instrumentés de sécurité: Selon une fréquencequi ne peut excéder un an, l’exploitant procède au contrôle de ces
# 33                                                                                 équipements de sécurités afin de s’assurer de leur bon fonctionnement.
# 34                                                                                                                                         Control of UPS
# 35                                                                                                           Contrôle du bon fonctionnement de l’onduleur
# 36                                                      Control of correct condition (absence of leakage or damages) andcorrect behavior of Pitch System.
# 37                                                                                      Contrôle du bon fonctionnement du système d’orientation des pales
# 38              Control of good behavior of Smoke Detector systems. Check that log“smoke detected” is registered in turbine controller (see operation log
# 39                                                                                                                                                  menu)
# 40                                                                                                                                Remarks: (as a comment)
# 41
#
#                  2
# 0
# 1
# 2
# 3
# 4               OK
# 5               OK
# 6
# 7               OK
# 8
# 9               OK
# 10              OK
# 11              OK
# 12
# 13              OK
# 14              OK
# 15
# 16
# 17  Not Applicable
# 18
# 19              OK
# 20              OK
# 21
# 22              OK
# 23              OK
# 24
# 25
# 26  Not Applicable
# 27              OK
# 28
# 29
# 30  Not Applicable
# 31
# 32              OK
# 33
# 34              OK
# 35              OK
# 36              OK
# 37              OK
# 38              OK
# 39
# 40
# 41  Not Applicable

# %%
formatted_table = vestas_report.format_table(full_table)

# %%
formatted_table
# Out:
#    item_number  \
# 0         0010
# 1            0
# 2         0.01
# 3            1
# 4         1.01
# 5         1.02
# 7         1.03
# 9         1.04
# 10        1.05
# 11        1.06
# 12           2
# 13        2.01
# 14        2.02
# 16        2.03
# 18           3
# 19        3.01
# 20        3.02
# 22        3.03
# 23        3.04
# 25        3.05
# 27        3.06
# 29        3.07
# 31           4
# 32        4.01
# 34        4.02
# 35        4.03
# 36        4.04
# 37        4.05
# 38        4.06
# 40        4.08
#
#                                                                                                                                                                                                                                                          inspection_detail  \
# 0                                                                                                                                                                                                                                           Check ICPE Electrical V112-3MW
# 1                                                                                                                                                                                                                                                                     eSIF
# 2                                                                                                                                                                                                                                                    0. DMS: 0093-0083 V03
# 3                                                                                                                                                                                                                                                                   Safety
# 4                                                                                                                                                                                                                                                     Two persons present.
# 5                                                                                           Trained in and aware of the contents of the Vestas Corporate OH and SManual including ‘Working with Hazardous Materials’ and Safety Regulations for Operators and Technicians.
# 7   Be sure to know the general recommendations regarding the followingpoints: For safety reasons, note the location of the emergency stop buttons. Please refer to documentation “Safety Regulations forOperators and Technicians” of the corresponding turbine platform.
# 9                                                                                                                                                                                                                                                 Locking of rotor/blades.
# 10                                                                                                                                                                                                                                                     Hearing protection.
# 11                                                                                                                                                                                                                                                        Hydraulic tools.
# 12                                                                                                                                                                                                                                                              Article 16
# 13                                                                                                                                                    Check that wind turbine is clean. Check that nocombustible orinflammable material is stored inside the wind turbine.
# 14                                                                                                             L'intérieur de l'aérogénérateur est maintenu propre. L'entreposage àl'intérieur de l'aérogénérateur de matériaux combustibles ou inflammables est interdit.
# 16                                                                                                                                                                                                                                                 Remarks: (as a comment)
# 18                                                                                                                                                                                                                                                              Article 17
# 19                                                                                                                                                                                                                                 Verify Stop Button is working properly.
# 20                                               Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt en application des préconisations du constructeur de l'aérogénérateur.
# 22                                                                                                                                                                                                                       Verify Emergency Stop Button is working properly.
# 23                                      Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt d'urgence en application des préconisations du constructeur del'aérogénérateur.
# 25                                                                                                                                                                                                                      Perform a VOG Test based on relevant platform SWI.
# 27                  Suivant une périodicité qui ne peut excéder 1 an, l'exploitant réalise destests pour vérifier l'état fonctionnel des équipements de mise à l'arrêt depuis un régime de survitesse en application des préconisations duconstructeur de l'aérogénérateur
# 29                                                                                                                                                                                                                                                 Remarks: (as a comment)
# 31                                                                                                                                                                                                                                                          Article 18 III
# 32                                                            Contrôle des systèmes instrumentés de sécurité: Selon une fréquencequi ne peut excéder un an, l’exploitant procède au contrôle de ces équipements de sécurités afin de s’assurer de leur bon fonctionnement.
# 34                                                                                                                                                                                                                                                          Control of UPS
# 35                                                                                                                                                                                                                            Contrôle du bon fonctionnement de l’onduleur
# 36                                                                                                                                                                       Control of correct condition (absence of leakage or damages) andcorrect behavior of Pitch System.
# 37                                                                                                                                                                                                       Contrôle du bon fonctionnement du système d’orientation des pales
# 38                                                                                                                         Control of good behavior of Smoke Detector systems. Check that log“smoke detected” is registered in turbine controller (see operation log menu)
# 40                                                                                                                                                                                                                                                 Remarks: (as a comment)
#
#             status
# 0
# 1
# 2
# 3
# 4               OK
# 5               OK
# 7               OK
# 9               OK
# 10              OK
# 11              OK
# 12
# 13              OK
# 14              OK
# 16  Not Applicable
# 18
# 19              OK
# 20              OK
# 22              OK
# 23              OK
# 25  Not Applicable
# 27              OK
# 29  Not Applicable
# 31
# 32              OK
# 34              OK
# 35              OK
# 36              OK
# 37              OK
# 38              OK
# 40  Not Applicable

# %%
output_path = Path("data") / "output"

vestas_report.save_inspection_data(formatted_table, output_path)

# %%
vestas_report.visualize_extraction_parameters(page_number=2)
