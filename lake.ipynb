# %% [markdown]
# ###  Data Lake

# %% [markdown]
# `initialisation`

# %%
from models import Lake; Lake().init()
# Out:
# Initializing the backend...
# Initializing provider plugins...
# - Reusing previous version of hashicorp/azuread from the dependency lock file
# - Reusing previous version of hashicorp/azurerm from the dependency lock file
# - Installing hashicorp/azuread v3.3.0...
# - Installed hashicorp/azuread v3.3.0 (signed by HashiCorp)
# - Installing hashicorp/azurerm v4.26.0...
# - Installed hashicorp/azurerm v4.26.0 (signed by HashiCorp)
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %% [markdown]
# `Plannification`

# %%
from models import Lake; Lake().plan()
# Out:
# data.azurerm_client_config.current: Reading...
# data.azurerm_client_config.current: Read complete after 0s [id=]
# azuread_application.app_keyvault: Refreshing state... [id=/applications/3b952904-46c5-431c-8104-f20e2abc77a2]
# azuread_application.app_datalake: Refreshing state... [id=/applications/c23b2d2c-12b7-47ce-9e1e-0a6fbe942af1]
# azurerm_storage_account.adls: Refreshing state... [id=/subscriptions/029b3537-0f24-400b-b624-6058a145efe1/resourceGroups/RG_DBREAU/providers/Microsoft.Storage/storageAccounts/wpdwindmanagerfradls]
# azuread_service_principal.sp_datalake: Refreshing state... [id=/servicePrincipals/14f51c55-d3e8-4d02-b93d-9375e3d425f7]
# ...

# %% [markdown]
# `Application`

# %%
from models import Lake; Lake().apply()
# Out:
# azurerm_storage_data_lake_gen2_path.folders["vestas/output/inspection_checklists"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["vestas/input"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["enercon/output/metadatas"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["enercon/input"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["vestas/output/metadatas"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["enercon/output/inspection_checklists"]: Creating...
# azurerm_storage_data_lake_gen2_path.folders["vestas/input"]: Creation complete after 3s [id=https://wpdwindmanagerfradls.dfs.core.windows.net/service-reports/vestas/input]
# azurerm_storage_data_lake_gen2_path.folders["enercon/output/inspection_checklists"]: Creation complete after 3s [id=https://wpdwindmanagerfradls.dfs.core.windows.net/service-reports/enercon/output/inspection_checklists]
# ...

# %% [markdown]
# <font color="lightcoral">🚨 Danger zone 🚨</font>

# %% [markdown]
# `Vider le conteneur`

# %%
from models import Lake; Lake().empty_container("service-reports")

# %% [markdown]
# `Destruction`

# %%
from models import Lake; Lake().destroy()
# Out:
# data.azurerm_client_config.current: Reading...
# data.azurerm_client_config.current: Read complete after 0s [id=]
# azuread_application.app_keyvault: Refreshing state... [id=/applications/9ae1144a-41db-484e-8077-fe3ee8689a8b]
# azuread_application.app_datalake: Refreshing state... [id=/applications/7ef0f629-b92b-4db7-b66e-758d0844c5fb]
# azurerm_storage_account.adls: Refreshing state... [id=/subscriptions/029b3537-0f24-400b-b624-6058a145efe1/resourceGroups/RG_DBREAU/providers/Microsoft.Storage/storageAccounts/wpdwindmanagerfradls]
# azuread_service_principal.sp_datalake: Refreshing state... [id=/servicePrincipals/fc83d7cd-adef-4e47-a863-1c1a05f153d6]
# ...
